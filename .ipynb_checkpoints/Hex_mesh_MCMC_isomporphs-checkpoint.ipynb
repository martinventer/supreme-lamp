# %% [markdown]
# # MCMC

# %%
from importlib import reload  
import Mesher

# %%
Mesher = reload(Mesher)

# %% [markdown]
# # Generate a Hex Mesh

# %%
myMesh = Mesher.make_hex_grid(2)
Mesher.plot_hex(myMesh)

# %% [markdown]
# # generate an active subset

# %%
active1 = Mesher.active_subset_random(myMesh, 3)
Mesher.plot_hex(myMesh, active=active1)

# %% [markdown]
# # create a graph

# %%
net = Mesher.make_hex_network(myMesh)
Mesher.plot_network(net)

# %% [markdown]
# ## plot network with active subset

# %%
Mesher.plot_network(net, active=active1)

# %% [markdown]
# ## plot subnet only

# %%
subnet1 = Mesher.get_active_sub_network(net, active=active1)
Mesher.plot_network(subnet1)
